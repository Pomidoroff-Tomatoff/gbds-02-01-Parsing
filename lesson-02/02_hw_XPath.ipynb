# %% [markdown]
# `GB` BigData / [Олег Гладкий](https://gb.ru/users/3837199) // домашнее задание

# %% [markdown]
# `262698` __Методы сбора и обработки данных из сети Интернет__:  `02`. Парсинг даных: HTML, DOM, __XPath__

# %% [markdown]
# # XPath: Парсер новостного сайта

# %% [markdown]
# Написать приложение или функцию, которые собирают основные новости с сайта на выбор:
#  * lenta.ru,
#  * yandex-новости.
#
# #### Получаемы данные
# Для парсинга использовать `XPath`. Структура данных в виде словаря должна содержать:
# - *название источника;
# - наименование новости;
# - ссылку на новость;
# - дата публикации.
#
# Минимум один сайт, максимум — все два

# %% [markdown]
# #### Проверка расположения интерпретатора Питона

# %%
# !where python
# Out:
# C:\Programs\Anaconda3\python.exe
# C:\Program Files\Python38\python.exe

# %% [markdown]
# #### Включаемы модули

# %%
import pandas as pd
from pprint import pprint 
import datetime

import requests
from lxml import html

# %% [markdown]
# ## 1. Лента.РУ
# `XPath` — Парсинг при его помощи!

# %% [markdown]
# ### Забираем все данные с сайта `Lenta.ru`

# %% [markdown]
#  Обращаемся к сайту как Хром методом `get` модуля `requests`. Кроме того:
#  * необходимо запомнить дату текущего запроса
#  * время этого текущего запроса
#  * для продолжения работы необходимо уточнить код ответа сервера `status_code`
#  * а так же необходимо уточнить, вернул ли нам сервер данные в формате `html`, информцию об этом сервер возвращает в заголовках `headers` в параметре `'Content-Type'`

# %%
# %%time
url = 'https://lenta.ru/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}

response = requests.get(url=url, headers=headers)

news_date = str(datetime.date.today())
news_time = str(datetime.datetime.now().strftime("%H:%M"))

response.status_code, response.headers['Content-Type'], response.url,
# Out:
# Wall time: 95.7 ms
# (200, 'text/html; charset=utf-8', 'https://lenta.ru/')

# %% [markdown]
# #### Перобразуем данные к формату `DOM`

# %% [markdown]
# Преобразование тела документа как строки в ответе `response.text` в _дерево_ `DOM` при помощи метода `fromstring` модуля `html`

# %%
dom = html.fromstring(response.text)

# %% [markdown]
# ### Парсим
# Выберем из дерева `DOM` только блоки с новостями. Каждый такой блок новостей — это объект. Все объекты объеденены в список `list`. При этом самым верхним уровнем в структуре для такого объекта будет не начало сайта или дерева `DOM`, а начало этого информационного блока — тэг `a`.

# %% [markdown]
# #### Функция
# Фукнция для выборки парснутых данных в новостные элементы

# %%
def eject(elements):
    ''' забираем первый элемент из списка'''
    if isinstance(elements, list):
        if len(elements) == 1 or len(elements) > 1:
            element = str(elements[0]).replace('\xa0', ' ')
        else:
            element = None
    return element

# %% [markdown]
# #### Блоки МИНИ
# Класс `card-mini__title` с минимальными новостями из нашего `DOM` в виде списка объектов:
# * Название новости
# * Ссылку
# * Время на текущий день.
#     - Новостной блок не содержит дату, а только время. Но мы располагаем датой запроса этих новостей, которую мы сохранили сразу после запроса в переменной `news_date`.
#     - Если время отсутствует в блоке с новостью, то воспользуемся временем запроса к сайту, сохранённого в переменной `news_time`.

# %% [markdown]
# __Блоки МИНИ__: все объекты с минимальными новостями

# %%
news_mini = dom.xpath('//a[contains(@class, "card-mini")]')
print(f"Блоки МИНИ: количество: {len(news_mini)}")
# Out:
# Блоки МИНИ: количество: 87

# %% [markdown]
# __Блоки МИНИ__: Парсим данные для кадой новости и сохраняем их как строку `DataFrame`.

# %%
news_mini_table = pd.DataFrame(columns=['Name', 'Link', 'Date', 'Source', 'N_Type']) # инициализирум выходную таблицу
news_type = "mini"

for i in news_mini:
    name = eject(i.xpath('.//div[contains(@class, "card-mini__text")]/span[contains(@class, "card-mini__title")]/text()'))
    link = url.strip('/') + eject(i.xpath('.//@href'))
    time = eject(i.xpath('.//div[contains(@class, "card-mini__text")]/div[contains(@class, "card-mini__info")]/time[contains(@class, "card-mini__date")]/text()'))
    
    date = news_date + ';' + (time if time else news_time) 

    news_mini_table = news_mini_table.append({'Date': date, 'Name': name, 'Link': link, 'N_Type': news_type}, ignore_index=True)

print(f"НОВОСТИ МИНИ: {len(news_mini_table)} позиция распарсена")

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# news_mini_table
# Out:
# НОВОСТИ МИНИ: 87 позиция распарсена

# %% [markdown]
# #### Блоки БИГ
# Новостные блоки БИГ: класс объектов `card-mini__big` с расширенными новостями из нашего `DOM` в виде 2-ого списка `list`.

# %%
news_big = dom.xpath('//a[contains(@class, "card-big")]')
print(f"Блоки БИГ, количество: {len(news_big)} объекта получено")
# Out:
# Блоки БИГ, количество: 52 объекта получено

# %% [markdown]
# Источник Source, переменная `src`: распарсить значение атрибута `xlink:href` тега `use`не получиться при помощи `xpath`, потому что, это не `htmp`. А это `xml`, который `XPATH` не понимает!
#
# Для доступа к этому «внешнему» тэгу `use` нужно обратиться к нему при помощи функции `name()` как `/*[name()="use"]` и обратиться к значению атрибута этого xml-тэга при помощи указателя `attribute::*` (это наверное указатель на любой атрибут).

# %%
news_big_table = pd.DataFrame(columns=['Name', 'Link', 'Date', 'Source', 'N_Type'], index=[]) # инициализирум выходную таблицу
news_type = "BIG"

for i in news_big:
    title = eject(i.xpath('.//div[contains(@class, "card-big__titles")]/h3[contains(@class, "card-big__title")]/text()'))
    notes = eject(i.xpath('.//div[contains(@class, "card-big__titles")]/span[@class]/text()'))
    time =  eject(i.xpath('.//div[contains(@class, "card-big__info")]/time[contains(@class, "card-big__date")]/text()'))
    link =  eject(i.xpath('.//@href'))
    
    # ??? Как получить доступ к значению атрибута xlink:href в ссылке xlink:href="#ui-label_motor" ???
    
    src =   eject(i.xpath('.//div[contains(@class, "card-big__info")]/*[name()="svg"]/*[name()="use"]/attribute::*'))   

    name  = title + (notes if notes else "")
    date = time
    link = url.strip("/") + link
    
    news_big_table = news_big_table.append({'Name': name, 'Link': link, 'Date': date, 'Source': src, 'N_Type': news_type}, ignore_index=True)

    
print(f"НОВОСТИ БИГ: {len(news_big_table)} позиция распарсена")
# news_big_table
# Out:
# НОВОСТИ БИГ: 52 позиция распарсена

# %% [markdown]
# ### ВСЕ НОВОСТИ: МИНИ + БИГ

# %%
news_table = news_mini_table.append(news_big_table, ignore_index=True)

# %%
print(f"ВСЕГО новостей: {len(news_table)}")
news_table
# Out:
# ВСЕГО новостей: 139
#                                                   Name  \
# 0    Британцев разозлила постановка «Ромео и Джулье...
# 1    Турция прокомментировал процесс вступления Фин...
# 2    Сотрудники посольства США посетили баскетболит...
# 3    Экс-возлюбленная Тимати показала лицо после ум...
# 4    Британия запретит своим компаниям перевозку ро...
# 70   Ирина Шейк снялась в прозрачной юбке для бренд...
# 71           Назначен новый главный редактор ИА Regnum
# 72   В Госдуме оценили идею продлить новогодние пра...
# 73   Военкор рассказал о работе ВДВ на артемовском ...
# 74   В Крыму у россиянина изъяли пять тысяч доз нар...
# 75                 Си Цзиньпин высказался о пути Китая
# 76   Объяснены успехи Европы в борьбе с газовым кри...
# 77   В Госдуме предрекли попытки Германии наладить ...
# 78   В трех регионах России резко выросли продажи а...
# 79   Зал повышенной комфортности в российском аэроп...
# 80   Кадыров раскритиковал за мягкость обсуждаемое ...
# 81           Узбекистан получил от США военную технику
# 82   Хакер из ДНР взломал аккаунт главнокомандующег...
# 83   Бывший легионер КХЛ ответил на критику за игру...
# 84   Природа оказалась под угрозой из-за могилы эль...
# 85   Врач предупредила о пагубных для здоровья посл...
# 86   Селена Гомес впервые прокомментировала совмест...
# 87   Нетаньяху выиграл на выборах и вернулся на пос...
# 88   В Крыму четырех ручных дельфинов выпустили в м...
# 89   «На зону вы уже не вернетесь» Российских заклю...
# 90   «Они понятия не имеют, как живут обычные люди»...
# 91   Лучи смерти. Как в России создают оружие будущ...
# 92   «Влиять можно на всех» Мир вступает в эпоху ин...
# 93   Рынок автомобилей в России изменился до неузна...
# 94   «Роняли гранаты, и они катились по полу» 20 ле...
# 95   «Сошел с ума и хочет меня убить» Что скрываетс...
# 96   «Мы стоим на историческом рубеже» Угроза ядерн...
# 97   «Хотите голых мужиков с фаллоимитаторами?» Как...
# 98   Журналист пропал после репоста записи экс-сотр...
# 99   Черный Лебедь. Таксист годами убивал и насилов...
# 100  «Мы снова бросаем вызов Западу» Борьба за неза...
# 101  Сталлоне и корона. Возвращение фон Триера, еще...
# 102  Истина в зерне. Россия приостановила свое учас...
# 103  Ввоз и ныне там. Из России ушли сотни западных...
# 104  Нехорошая жена. В сети — окруженная скандалами...
# 105  Суперкары на дизеле: бывает и такое! Десять бы...
# 106  С диагнозом по жизни. Как в России относятся к...
# 107  «Внимание! Это не учебная тревога!» Как собрат...
# 108  «По утрам там пахнет карамелью» Где находятся ...
# 109  Автомобили, которые переросли сами себя 10 маш...
# 110  Из больницы — в налоговую. Как вернуть деньги,...
# 111  Пожар, потоп, суд. Что делать, если ушлые сосе...
# 112  «Дышать тут неприятно, но довольно интересно» ...
# 113  Неизвестные факты о рождении Нивы Комбайн Нива...
# 114  «Картавых у нас по-прежнему больше всего» Стол...
# 115  Крутота по-американски: Cadillac празднует 120...
# 116  «Там, где был автобусный парк, появится музей»...
# 117  Неожиданная техника с мотором от Dodge Viper Д...
# 118  «Дворниками были даже Лужков с Солженицыным» И...
# 119  Видео: один день с экскаватором-гигантом Знако...
# 120  «Женственность сейчас воспринимается как слабо...
# 121  Остин Пауэрс: обзор Гран-при США В техасском О...
# 122  Навязчивость, хамство и память золотой рыбки. ...
# 123  «Набираю команду, будем делать кэш» Как инфоцы...
# 124  Необычные пикапы: грузовые Bentley, Toyota Lan...
# 125  Ограничения по счету. Сбер назвал 6 причин и р...
# 126  Модель поддержала революцию в Мьянме со сцены ...
# 127  Расти и предпринимай. У российской молодежи по...
# 128  От «Вездехода» к «Армате». Как за сто лет росс...
# 112    00:05, 2 ноября 2022   #ui-label_moslenta    BIG
# 113    08:47, 1 ноября 2022      #ui-label_motor    BIG
# 114    00:05, 1 ноября 2022   #ui-label_moslenta    BIG
# 115  09:28, 31 октября 2022      #ui-label_motor    BIG
# 116  00:05, 31 октября 2022   #ui-label_moslenta    BIG
# 117  07:54, 30 октября 2022      #ui-label_motor    BIG
# 118  00:05, 30 октября 2022   #ui-label_moslenta    BIG
# 119  15:09, 29 октября 2022      #ui-label_motor    BIG
# 120  00:05, 29 октября 2022   #ui-label_moslenta    BIG
# 121  14:02, 28 октября 2022      #ui-label_motor    BIG
# 122  08:43, 28 октября 2022  #ui-label_secretmag    BIG
# 123  08:43, 28 октября 2022  #ui-label_secretmag    BIG
# 124  07:50, 28 октября 2022      #ui-label_motor    BIG
# 125                   13:56                 None    BIG
# 126    00:01, 2 ноября 2022                 None    BIG
# 127  17:06, 31 октября 2022                 None    BIG
# 128    00:03, 2 ноября 2022                 None    BIG
# 129    00:01, 1 ноября 2022                 None    BIG
# 130    00:01, 1 ноября 2022                 None    BIG
# 131    00:01, 1 ноября 2022                 None    BIG
# 132  23:02, 31 октября 2022                 None    BIG
# 133    00:01, 1 ноября 2022                 None    BIG
# 134    14:37, 1 ноября 2022                 None    BIG
# 135  00:01, 31 октября 2022                 None    BIG
# 136  10:58, 31 октября 2022                 None    BIG
# 137  00:01, 31 октября 2022                 None    BIG
# 138  00:01, 31 октября 2022                 None    BIG

# %% [markdown]
# <!--  -->

# %% [markdown]
# __P.S.__
#
# Не удалось распарсить значение атрибута `xlink:href` тега `use` — как только не пытался при помощи `xpath`... Потому что, это не `html`, а `xml`, который `XPATH` не разбирает.
#
# Подсмотрел...

# %% [markdown]
# <!--  -->

# %% [markdown]
# ## 2. Yandex-новости
# `XPath`. (Работа после сдачи ДЗ)

# %% [markdown]
# Теперь это dzen
# Для DZEN требуется авторизация для подбора контента под пользователя. И Дзен, вместо новостей, перенаправляет на страничку авторизации.
#
# Чтобы избежать авторизации и получить универсальный контент, нужно передать параметр `'sso_failed'` со значением — пустая строка (`""`)

# %%
# %%time
url = 'https://yandex.ru/news/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}

params = {
    'sso_failed': '',
}

response = requests.get(url=url, headers=headers, params=params)
dom = html.fromstring(response.text)

news_date = str(datetime.date.today())
news_time = str(datetime.datetime.now().strftime("%H:%M"))

response.status_code, response.headers['Content-Type'], response.url,
# Out:
# Wall time: 357 ms
# (200,
#  'text/html; charset=UTF-8',
#  'https://dzen.ru/news/?issue_tld=ru&sso_failed=')

# %%
# response.text

# %% [markdown]
# #### Все объекты-контейнеры с новостью

# %%
news_dzen = dom.xpath('.//div[contains(@class, "mg-card ")]')
print(f"Блоки DZEN: количество: {len(news_dzen)}")
# Out:
# Блоки DZEN: количество: 65

# %%
for i in news_dzen:
    name = eject(i.xpath('.//h2/a/text()'))
    #     text = i.xpath('.//div[contains(@class, "mg-card__text-content")]/div[contains(@class,"mg-card__text")]/h2/a/text()')  # [0].replace('\xa0', ' ')
    print(name)
    
    

#     name = i.xpath('.//h2[contains(@class, "mg-card__title")]/a/text()')    
#     name = i.xpath('.//div[contains(@class, "mg-card__text")]/div[contains(@class, "mg-card__annotation")]/text()')
# Out:
# Главе Чечни Кадырову присвоили звание генерал-полковника
# Правозащитник Чиков заявил о первом уголовном деле за уклонение от мобилизации в России
# Путин признался, что результаты референдумов на новых территориях его порадовали и удивили
# Минобороны: на Андреево-Криворожском направлении войска удерживают занимаемые позиции
# Песков опроверг сообщения о новом обращении Путина по смене статуса спецоперации
# Подмосковный педагог стал победителем конкурса «Учитель года России – 2022»
# Андрей Воробьев поздравил учителей с профессиональным праздником и вручил награды
# Полиция задержала подозреваемого в сбыте примерно 1 кг кокаина в Клину
# Замминистра обороны РФ напутствовал мобилизованных в Коломне
# Подозреваемого в краже кофе и зубной пасты задержали в Коломне
# Катапульта отправила в небо спутники НАСА
# Актер Стас Ярушин поделился историей создания песни «Я и ты» для телесериала «Универ»
# Spiked: консерваторы из Британии бьются в «предсмертной агонии»
# Путин подписал указ об отсрочке от частичной мобилизации для некоторых категорий учащихся
# Французская актриса Жюльет Бинош отрезала волосы в знак поддержки протестов в Иране
# Politico: постпреды стран ЕС согласовали новые антироссийские санкции
# Генерал Картаполов призвал прекратить врать о ходе спецоперации на Украине
# FT: США подталкивают Украину к генеральному сражению с Россией на юге до наступления зимы
# Кулеба заявил об ударе дронами-камикадзе по казарме ВСУ в городе Белая Церковь под Киевом
# Экс-аналитик Пентагона Квятковски: включение новых регионов России способствует их обороне
# В Минэке заявили о недооцененном экономическом потенциале присоединенных территорий
# EUobserver сообщил об исключении из нового пакета антироссийских санкций компании «Алроса»
# РИА Новости: бывший ректор ВГИКа Новиков скончался в Москве
# CNN сообщил о попытках США отговорить ОПЕК+ от голосования за сокращение нефтедобычи
# В ООН помешали Литве снести крупнейший в стране мемориал солдатам СССР
# FT: Саудовская Аравия и Россия объявят о резком сокращении добычи нефти
# Российские ювелирные сети сократили число магазинов
# Катар пообещал стабильно поставлять в Европу до 15 миллионов тонн природного газа
# Росрыболовство разработает новую систему подсчета улова и производства рыбы
# Минфин предложил отказаться от 30% скидки на оплату пошлин через Госуслуги
# Володин считает, что США не планируют возвращать превысивший $31 трлн госдолг
# Канцлер Шольц назвал неспособности создать развитую инфраструктуру импорта газа ошибкой
# FP: Словакия и Чехия из-за роста цен на энергоресурсы могут отказаться от поддержки Киева
# «Газпром» объявил о возобновлении транспортировки газа через Австрию
# Президент Сербии заявил о вероятности нового варианта «Сталинградской битвы»
# Международная ассоциация бокса допустила к соревнованиям спортсменов из России и Беларуси
# Украина совместно с Испанией и Португалией подала заявку на проведение ЧМ-2030 по футболу
# Шахматист из США Ниманн обвиняется в ста случаях мошенничества в онлайн-матчах
# КХЛ оштрафовала главного тренера СКА Ротенберга за непристойный жест в матче с ЦСКА
# Марокканский волейболист «Белогорья» Мохамед Аль Хачдади назвал Россию удивительной
# Экс-глава Новосибирского облсуда Римма Шатовкина приговорена к условному сроку
# Шведский член Европарламента Аль-Сахлани отрезала волосы в поддержку протестов в Иране
# СКР нашел пыточную тюрьму на базе украинского нацбата «Айдар» в мясном цеху в ЛНР
# ФСБ задержала при получении взятки замначальника полиции ГУ МВД по Красноярскому краю
# Mash: двух мобилизованных увезли из воинской части под Москвой в предынфарктном состоянии
# Новым ведущим шоу «Сто к одному» стал продюсер «Бригады» Акопов
# Песни братьев Меладзе и Аллы Пугачевой сняты со всех российских радиостанций
# Фильм Евгения Пригожина про ЧВК «Вагнер» оказался мощным антивоенным высказыванием
# Начались съёмки сериала «Кеша» в постановке Константина Богомолова
# На Байконуре завершились съемки фильма «Вызов» с Юлией Пересильд
# The Verge: первым смартфоном Apple с USB-C окажется iPhone 17, который выйдет в 2025 году
# CD Projekt RED анонсировала новые игры во вселенных Cyberpunk 2077 и «Ведьмака»
# На «Авито» запустили выкуп и перепродажу телефонов своих пользователей
# Кибераналитик Новиков: мошенники могут выяснить местоположение абонента по номеру телефона
# Electronic Arts представила геймплейный ролик ремейка Dead Space
# Нобелевскую премию по химии присудили за клик-химию
# Российские ученые создали цифровую модель оптимизации нефтедобычи
# Университет Пердью создал белую краску, остужающую поверхности на 4,5 °C
# National Science Review: суперконтинент Амазия образуется на месте Тихого океана
# В России создали технологию персонализированного питания
# «Ъ»: автодилерам в России не хватает продавцов подержанных автомашин в 2022 году
# Autonews: изъять автомобили для нужд армии у россиян могут только при военном положении
# Компания MERCEDES-BENZ представила обновленный компактвэн MERCEDES-BENZ B-Class 2023 года
# Компания MASERATI представила новый MASERATI GranTurismo с мотором V6 Nettuno
# Автозавод «Москвич» начал формирование дилерской сети

# %% [markdown]
# ## 3. books.toscrape.com
# `XPath` (Работа после сдачи ДЗ)

# %% [markdown]
# Учебный сайт для парсинга, объект парсинга — книги...

# %%
# %%time
url = 'http://books.toscrape.com/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36',
}
response = requests.get(url=url, headers=headers)
# Out:
# CPU times: total: 46.9 ms
# Wall time: 854 ms

# %%
response.status_code, response.headers['Content-Type'], response.url, response.encoding
# Out:
# (200, 'text/html', 'http://books.toscrape.com/', 'ISO-8859-1')

# %% [markdown]
# Изменим кодировку на __Юникод__:

# %%
response.encoding = 'utf-8'

# %%
dom = html.fromstring(response.text)

# %%
books = dom.xpath('//ol[@class="row"]/li')
len(books)
# Out:
# 20

# %%
books_table = pd.DataFrame()
book_info = {}

for book in books:
    title = book.xpath('.//h3/a/@title')[0]
    price = book.xpath('.//p[@class="price_color"]/text()')[0]
#     .decode('utf8')
#     .encode('utf8')
    
    book_info = {
        'title': title,
        'price': price,
    }
    book_info = pd.DataFrame([book_info])
    books_table = pd.concat([books_table, book_info], axis=0, ignore_index=True)


books_table
# Out:
#                                                 title   price
# 0                                A Light in the Attic  £51.77
# 1                                  Tipping the Velvet  £53.74
# 2                                          Soumission  £50.10
# 3                                       Sharp Objects  £47.82
# 4               Sapiens: A Brief History of Humankind  £54.23
# 5                                     The Requiem Red  £22.65
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60
# 9                                     The Black Maria  £52.15
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99
# 11                              Shakespeare's Sonnets  £20.66
# 12                                        Set Me Free  £17.46
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  £52.29
# 14                          Rip it Up and Start Again  £35.02
# 15  Our Band Could Be Your Life: Scenes from the A...  £57.25
# 16                                               Olio  £23.88
# 17  Mesaerion: The Best Science Fiction Stories 18...  £37.59
# 18                       Libertarianism for Beginners  £51.33
# 19                            It's Only the Himalayas  £45.17
